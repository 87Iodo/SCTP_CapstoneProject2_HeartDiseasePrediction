# %% [markdown]
# <table class="table table-bordered">
#     <tr>
#         <th style="text-align:center; width:35%"><img src='https://mma.prnewswire.com/media/1860917/NTUC_LHUB_Logo.jpg' style="width: 350px; height: 125px; "></th>
#         <th style="text-align:center;"><h1>Project 2 - Healthcare - Predictive Analytics</h1><h2>A Data Analysis - Building Models  </h2><h3></h3></th>
#     </tr>
# </table>

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load data
cardio_df = pd.read_csv('cardio_cleaned_ClusterAfterSplit.csv')

# %%
cardio_df.head(1)
# Out:
#    active  alco  cholesterol  gluc  smoke  disease  ap_pulse  ap_map  BMI  \
# 0       1     0            1     1      0        0         1       2    1
#
#    age_group
# 0          4

# %% [markdown]
# # Spliting data

# %%
from sklearn.model_selection import train_test_split

# %%
SEED = 42

# %%
# The dataset will be split into 50% training, 50% testing
#x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y, random_state=42)
xy_train, xy_test = train_test_split(cardio_df, test_size=0.5, random_state=SEED)

# %%
xy_train.shape
# Out:
# (30071, 10)

# %%
xy_test.shape
# Out:
# (30071, 10)

# %% [markdown]
# # Clustering

# %% [markdown]
# <font color="blue">A new feature is introduced by using Clustering technique in data preprocessing.
#
# <font color="blue">KMode thats is a clustering algorithm is used for clustering categorical data. Unlike traditional clustering algorithms like KMeans that work with numerical data, KModes is designed to handle categorical variables directly. It is based on the k-modes algorithm, which aims to partition the data into clusters of similar items where the similarity is measured by the number of matching categories between data points.

# %%
#Clustering
from kmodes.kmodes import KModes

# %% [markdown]
# <font color = 'blue'>To find the optimal number of clusters, elbow method and kneed algorithm are used.

# %%
cost = []
num_clusters = range(1,11) # 1 to 5
for i in list(num_clusters):
    kmode = KModes(n_clusters=i, init = "Huang", n_init = 5, verbose=0,random_state=SEED)
    kmode.fit_predict(xy_train)
    cost.append(kmode.cost_)

plt.plot(num_clusters, cost, 'bo-')
plt.xlabel('num_clusters')
plt.ylabel('Cost')
plt.title('Elbow Method For Optimal Number of Clusters')
plt.show()

# %%
from kneed import KneeLocator

# %%
kl = KneeLocator(
   range(1, 11), cost, curve="convex", direction="decreasing"
   )
kl.elbow
# Out:
# 4

# %% [markdown]
# 4 or 6 clusters might be a good choice for the number of clusters.

# %%
#Building KModes model
km = KModes(n_clusters=6, init = "Huang", n_init = 5,random_state=SEED)
xy_train['clusters'] = km.fit_predict(xy_train)
xy_test['clusters'] = km.fit_predict(xy_test)

# %%
display(xy_train.head(1))
display(xy_test.head(1))
# Out:
#       active  alco  cholesterol  gluc  smoke  disease  ap_pulse  ap_map  BMI  \
# 3984       1     0            1     1      0        0         2       3    2
#
#       age_group  clusters
# 3984          5         3
#        active  alco  cholesterol  gluc  smoke  disease  ap_pulse  ap_map  BMI  \
# 31483       0     0            1     1      0        1         3       3    2
#
#        age_group  clusters
# 31483          3         3

# %% [markdown]
# # Define x and y

# %%
# define x and y
x_train = xy_train.drop('disease', axis=1)
y_train = xy_train['disease']
x_test = xy_test.drop('disease', axis=1)
y_test = xy_test['disease']

# %%
x_train.head(1)
# Out:
#       active  alco  cholesterol  gluc  smoke  ap_pulse  ap_map  BMI  \
# 3984       1     0            1     1      0         2       3    2
#
#       age_group  clusters
# 3984          5         3

# %%
x_test.head(1)
# Out:
#        active  alco  cholesterol  gluc  smoke  ap_pulse  ap_map  BMI  \
# 31483       0     0            1     1      0         3       3    2
#
#        age_group  clusters
# 31483          3         3

# %% [markdown]
# # Scaling data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(x_train)
# Out:
# MinMaxScaler()

# %%
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# # Build Baseline Model

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg_baseline = LogisticRegression(random_state=SEED)

# %%
lg_baseline.fit(x_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %% [markdown]
# # Evaluate Model Performance with Cross-validation and using Test Data

# %%
from sklearn.model_selection import cross_validate, KFold

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=SEED)

# %%
# Access various information including fit times and predict times
cv_results = cross_validate(lg_baseline, x_train, y_train, cv=kfold, scoring=['accuracy'], return_train_score=True, n_jobs=-1)

# %% [markdown]
# <font color="blue">CV Accuracy:

# %%
print("Training Score:", cv_results['train_accuracy'].mean())
print("Test Score:", cv_results['test_accuracy'].mean())
print("Fit Time:", cv_results['fit_time'].mean(), 'seconds')
print("Predict Time:", cv_results['score_time'].mean(), 'seconds')
# Out:
# Training Score: 0.78802668688193
# Test Score: 0.7875361866921213
# Fit Time: 0.07870140075683593 seconds
# Predict Time: 0.003091907501220703 seconds

# %% [markdown]
# <font color="blue">Test Data Accuracy:

# %%
print('Training Accuracy: ',lg_baseline.score(x_train,y_train), '\nTest Accuracy: ', lg_baseline.score(x_test,y_test))
# Out:
# Training Accuracy:  0.7873698912573576
# Test Accuracy:  0.8396129160985667

# %% [markdown]
# # Build Other Models

# %%
#KNN Classification
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier()
KNN.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
print('Training Accuracy: ',KNN.score(x_train,y_train), '\nTest Accuracy: ', KNN.score(x_test,y_test))
# Out:
# Training Accuracy:  0.9443650028266436
# Test Accuracy:  0.8514183099996675

# %%
#Support Vector Machine
from sklearn.svm import SVC
svc = SVC(random_state=SEED)
svc.fit(x_train,y_train)
# Out:
# SVC(random_state=42)

# %%
print('Training Accuracy: ',svc.score(x_train,y_train), '\nTest Accuracy: ', svc.score(x_test,y_test))
# Out:
# Training Accuracy:  0.8877656213627748
# Test Accuracy:  0.8631571946393535

# %%
#Decision Tree
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state=SEED)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
print('Training Accuracy: ',dt.score(x_train,y_train), '\nTest Accuracy: ', dt.score(x_test,y_test))
# Out:
# Training Accuracy:  0.9631206145455755
# Test Accuracy:  0.8938512187822154

# %%
#naive bayes (Gaussian)
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
print('Training Accuracy: ',gnb.score(x_train,y_train), '\nTest Accuracy: ', gnb.score(x_test,y_test))
# Out:
# Training Accuracy:  0.7743008213893785
# Test Accuracy:  0.7822486781284294

# %%
#naive bayes (multinomial)
from sklearn.naive_bayes import MultinomialNB
mnb = MultinomialNB()
mnb.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
print('Training Accuracy: ',mnb.score(x_train,y_train), '\nTest Accuracy: ', mnb.score(x_test,y_test))
# Out:
# Training Accuracy:  0.6144790662099697
# Test Accuracy:  0.6461042200126368

# %%
#Ramdom Forest
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=SEED)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
cv_results = cross_validate(rf, x_train, y_train, cv=kfold, scoring=['accuracy'], return_train_score=True, n_jobs=-1)

# %%
print("Training Score:", cv_results['train_accuracy'].mean())
print("Test Score:", cv_results['test_accuracy'].mean())
print("Fit Time:", cv_results['fit_time'].mean(), 'seconds')
print("Predict Time:", cv_results['score_time'].mean(), 'seconds')
# Out:
# Training Score: 0.9639935458960615
# Test Score: 0.9502510269056325
# Fit Time: 3.550284242630005 seconds
# Predict Time: 0.25343031883239747 seconds

# %%
print('Training Accuracy: ',rf.score(x_train,y_train), '\nTest Accuracy: ', rf.score(x_test,y_test))
# Out:
# Training Accuracy:  0.9631206145455755
# Test Accuracy:  0.895846496624655

# %%
#Gradient Boosting
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier(random_state=SEED)
gb.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
print('Training Accuracy: ',gb.score(x_train,y_train), '\nTest Accuracy: ', gb.score(x_test,y_test))
# Out:
# Training Accuracy:  0.9508164011838649
# Test Accuracy:  0.9042266635629012

# %%
#XGBoost
from xgboost import XGBClassifier
xgb = XGBClassifier(random_state=SEED)
xgb.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
print('Training Accuracy: ',xgb.score(x_train,y_train), '\nTest Accuracy: ', xgb.score(x_test,y_test))
# Out:
# Training Accuracy:  0.9587975125536231
# Test Accuracy:  0.9040936450400718

# %%
#lightgbm
import lightgbm
lgbm = lightgbm.LGBMClassifier()
lgbm.fit(x_train,y_train)
# Out:
# [LightGBM] [Info] Number of positive: 14645, number of negative: 15426
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003197 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 43
# [LightGBM] [Info] Number of data points in the train set: 30071, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.487014 -> initscore=-0.051955
# [LightGBM] [Info] Start training from score -0.051955
# LGBMClassifier()

# %%
print('Training Accuracy: ',lgbm.score(x_train,y_train), '\nTest Accuracy: ', lgbm.score(x_test,y_test))
# Out:
# Training Accuracy:  0.9577001097402813
# Test Accuracy:  0.9039273718865352

# %% [markdown]
# # Model Performance Summary by Test Data

# %%
models = [lg_baseline, KNN, svc, dt, gnb, mnb, rf, gb, xgb, lgbm]
model_names = [type(model).__name__ for model in models]
result_table_Test = pd.DataFrame(columns=['Model','Training Accuracy','Test Accuracy'])

for model, m_name in zip(models, model_names):
    train_accu = model.score(x_train,y_train)
    test_accu = model.score(x_test,y_test)
    result_table_Test = pd.concat([result_table_Test,pd.DataFrame({'Model':[m_name], 'Training Accuracy':[train_accu],
                                                         'Test Accuracy':[test_accu]})],ignore_index=True)

# %%
result_table_Test_sorted = result_table_Test.sort_values(by='Test Accuracy', ascending = False)
display(result_table_Test_sorted)
# Out:
#                         Model  Training Accuracy  Test Accuracy
# 7  GradientBoostingClassifier           0.950816       0.904227
# 8               XGBClassifier           0.958798       0.904094
# 9              LGBMClassifier           0.957700       0.903927
# 6      RandomForestClassifier           0.963121       0.895846
# 3      DecisionTreeClassifier           0.963121       0.893851
# 2                         SVC           0.887766       0.863157
# 1        KNeighborsClassifier           0.944365       0.851418
# 0          LogisticRegression           0.787370       0.839613
# 4                  GaussianNB           0.774301       0.782249
# 5               MultinomialNB           0.614479       0.646104

# %%
plt.barh(width=result_table_Test_sorted['Test Accuracy'],y=result_table_Test_sorted['Model'], alpha=0.3, height=0.3, label='Test Accuracy')
plt.barh(width=result_table_Test_sorted['Training Accuracy'],y=result_table_Test_sorted['Model'],align='edge', alpha=0.3, height=0.3, label='Training Accuracy')
plt.legend(loc='upper left')
plt.xlabel('Accuracy - higher is better')
plt.show()

# %% [markdown]
# # Model Performance Summary by CV

# %%
models = [lg_baseline, KNN, svc, dt, gnb, mnb, rf, gb, xgb, lgbm]
model_names = [type(model).__name__ for model in models]
result_table = pd.DataFrame(columns=['Model','Training Accuracy','Test Accuracy','Fit Time (seconds)','Predict Time (seconds)','Total time taken (seconds)'])

for model, m_name in zip(models, model_names):
    cv_results = cross_validate(model, x_train, y_train, cv=kfold, scoring=['accuracy'], return_train_score=True, n_jobs=-1)
    train_accu = cv_results['train_accuracy'].mean()
    test_accu = cv_results['test_accuracy'].mean()
    fit = cv_results['fit_time'].mean()
    pred = cv_results['score_time'].mean()
    total = fit + pred
    result_table = pd.concat([result_table,pd.DataFrame({'Model':[m_name], 'Training Accuracy':[train_accu],
                                                         'Test Accuracy':[test_accu],'Fit Time (seconds)':[fit], 'Predict Time (seconds)':[pred],
                                                        'Total time taken (seconds)':[total]})],ignore_index=True)

# %%
result_table_sorted = result_table.sort_values(by='Test Accuracy', ascending = False)
display(result_table_sorted)
# Out:
#                         Model  Training Accuracy  Test Accuracy  \
# 9              LGBMClassifier           0.958132       0.953710
# 8               XGBClassifier           0.959704       0.952745
# 7  GradientBoostingClassifier           0.951191       0.950949
# 6      RandomForestClassifier           0.963994       0.950251
# 3      DecisionTreeClassifier           0.963994       0.947990
# 1        KNeighborsClassifier           0.942669       0.928070
# 2                         SVC           0.879818       0.878288
# 0          LogisticRegression           0.788027       0.787536
# 4                  GaussianNB           0.776338       0.775564
# 5               MultinomialNB           0.618237       0.618203
#
#    Fit Time (seconds)  Predict Time (seconds)  Total time taken (seconds)
# 9            0.988059                0.024398                    1.012457
# 8            0.566471                0.043747                    0.610218
# 7            4.000268                0.022472                    4.022740
# 6            2.603877                0.209990                    2.813867
# 3            0.040418                0.009376                    0.049795
# 1            0.243216                5.200982                    5.444199
# 2           63.393592               18.559780                   81.953372
# 0            0.087499                0.003125                    0.090624
# 4            0.013081                0.003123                    0.016203
# 5            0.021875                0.000000                    0.021875

# %%
plt.subplot(1,2,1)
plt.barh(width=result_table_sorted['Test Accuracy'],y=result_table_sorted['Model'], alpha=0.3, height=0.3, label='Test Accuracy')
plt.barh(width=result_table_sorted['Training Accuracy'],y=result_table_sorted['Model'],align='edge', alpha=0.3, height=0.3, label='Training Accuracy')
plt.legend(loc='upper left')
plt.xlabel('Accuracy - higher is better')
plt.subplot(1,2,2)
plt.plot(result_table_sorted['Fit Time (seconds)'],result_table_sorted['Model'], marker='o', label='Fit Time')
plt.plot(result_table_sorted['Predict Time (seconds)'],result_table_sorted['Model'], marker='x', label='Predict Time')
plt.legend()
plt.xlabel('Time - lower is better')
plt.subplots_adjust(wspace=0.5, right=2)
plt.show()

# %% [markdown]
# <font color="blue">We will select XGBClassifier, Logistic Regression, Decision Tree, Random Forest, and K-NearestNeighbours for Hyperparameter Optimization

# %% [markdown]
# # Hyperparameters Optimization by CV

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

# Define the classifiers
classifiers = {
    'XGBClassifier': XGBClassifier(random_state=SEED),
    'LogisticRegression': LogisticRegression(random_state=SEED),
    'DecisionTreeClassifier': DecisionTreeClassifier(random_state=SEED),
    'RandomForestClassifier': RandomForestClassifier(random_state=SEED),
    'KNeighborsClassifier': KNeighborsClassifier()
}

# Define the parameter grids for each classifier
param_grids = {
    'XGBClassifier': {'classifier__max_depth': [3, 5, 7], 'classifier__learning_rate': [0.1, 0.01, 0.05],
                     'classifier__n_estimators': [100,200,300], 'classifier__min_child_weight': [1,3,5],
                     'classifier__gamma': [0.0, 0.1, 0.2], 'classifier__subsample': [0.8,0.9,1.0],
                     'classifier__colsample_bytree': [0.8,0.9,1.0]},
    'LogisticRegression': {'classifier__C': [1, 10, 20], 'classifier__solver': ['lbfgs', 'liblinear']},
    'DecisionTreeClassifier': {'classifier__max_depth': [3, 5, 25], 'classifier__max_leaf_nodes': [10,20,100]},
    'RandomForestClassifier': {'classifier__n_estimators': [100,300,500], 'classifier__max_depth': [3, 10, 50], 'classifier__max_leaf_nodes': [20,100,250]},
    'KNeighborsClassifier': {'classifier__n_neighbors': [5, 30, 50], 'classifier__weights': ['uniform','distance']}
}

# Create pipelines for each classifier
pipelines = {name: Pipeline([('classifier', clf)]) for name, clf in classifiers.items()}

# Perform grid search for each classifier
results = {}
for name, pipeline in pipelines.items():
    grid_search = GridSearchCV(pipeline, param_grids[name], cv=5, scoring='accuracy', n_jobs=-1)
    grid_search.fit(x_train, y_train)
    results[name] = {
        'best_params': grid_search.best_params_,
        'best_score': grid_search.best_score_,
        'cv_results': grid_search.cv_results_
    }

# %%
results
# Out:
# {'XGBClassifier': {'best_params': {'classifier__colsample_bytree': 0.9,
#    'classifier__gamma': 0.0,
#    'classifier__learning_rate': 0.1,
#    'classifier__max_depth': 5,
#    'classifier__min_child_weight': 3,
#    'classifier__n_estimators': 100,
#    'classifier__subsample': 0.8},
#   'best_score': 0.9555051844946995,
#   'cv_results': {'mean_fit_time': array([0.49240975, 0.46510329, 0.29285312, ..., 3.36929498, 3.18942432,
#           1.94467368]),
#    'std_fit_time': array([0.01694425, 0.01052629, 0.00300151, ..., 0.06409753, 0.31923552,
#           0.01960605]),
#    'mean_score_time': array([0.02000594, 0.02072735, 0.00937438, ..., 0.17186942, 0.14543185,
#           0.09907856]),
#    'std_score_time': array([0.00947575, 0.00473773, 0.00765415, ..., 0.01397505, 0.04653232,
#           0.01312475]),
#    'param_classifier__colsample_bytree': masked_array(data=[0.8, 0.8, 0.8, ..., 1.0, 1.0, 1.0],
#                 mask=[False, False, False, ..., False, False, False],
#           fill_value='?',
#                dtype=object),
#    'param_classifier__gamma': masked_array(data=[0.0, 0.0, 0.0, ..., 0.2, 0.2, 0.2],
#                 mask=[False, False, False, ..., False, False, False],
#           fill_value='?',
#                dtype=object),
#    'param_classifier__learning_rate': masked_array(data=[0.1, 0.1, 0.1, ..., 0.05, 0.05, 0.05],
#                 mask=[False, False, False, ..., False, False, False],
#           fill_value='?',
#                dtype=object),
#    'param_classifier__max_depth': masked_array(data=[3, 3, 3, ..., 7, 7, 7],
#                 mask=[False, False, False, ..., False, False, False],
#           fill_value='?',
#                dtype=object),
#    'param_classifier__min_child_weight': masked_array(data=[1, 1, 1, ..., 5, 5, 5],
#                 mask=[False, False, False, ..., False, False, False],
#           fill_value='?',
#                dtype=object),
#    'param_classifier__n_estimators': masked_array(data=[100, 100, 100, ..., 300, 300, 300],
#                 mask=[False, False, False, ..., False, False, False],
#           fill_value='?',
#                dtype=object),
#    'param_classifier__subsample': masked_array(data=[0.8, 0.9, 1.0, ..., 0.8, 0.9, 1.0],
#                 mask=[False, False, False, ..., False, False, False],
#           fill_value='?',
#                dtype=object),
#    'params': [{'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
# ...
#     {'classifier__C': 10, 'classifier__solver': 'lbfgs'},
#     {'classifier__C': 10, 'classifier__solver': 'liblinear'},
#     {'classifier__C': 20, 'classifier__solver': 'lbfgs'},
#     {'classifier__C': 20, 'classifier__solver': 'liblinear'}],
#    'split0_test_score': array([0.79035744, 0.78836243, 0.79035744, 0.79035744, 0.79035744,
#           0.79035744]),
#    'split1_test_score': array([0.78417027, 0.78383771, 0.78400399, 0.78417027, 0.78400399,
#           0.78400399]),
#    'split2_test_score': array([0.79165281, 0.79215165, 0.79181909, 0.79181909, 0.79181909,
#           0.79181909]),
#    'split3_test_score': array([0.78732956, 0.78732956, 0.78732956, 0.78732956, 0.78732956,
#           0.78732956]),
#    'split4_test_score': array([0.78350515, 0.78300632, 0.78367143, 0.78367143, 0.78367143,
#           0.78367143]),
#    'mean_test_score': array([0.78740305, 0.78693753, 0.7874363 , 0.78746956, 0.7874363 ,
#           0.7874363 ]),
#    'std_test_score': array([0.00323848, 0.00329952, 0.00327745, 0.00324311, 0.00327745,
#           0.00327745]),
#    'rank_test_score': array([5, 6, 2, 1, 2, 2])}},
#  'DecisionTreeClassifier': {'best_params': {'classifier__max_depth': 25,
#    'classifier__max_leaf_nodes': 100},
#   'best_score': 0.9538092525033719,
#   'cv_results': {'mean_fit_time': array([0.06243024, 0.05957685, 0.06546931, 0.06876287, 0.07449822,
#           0.07664323, 0.08269377, 0.08748937, 0.06561904]),
#    'std_fit_time': array([0.00988007, 0.00356718, 0.00734991, 0.00765291, 0.01090107,
#           0.0012204 , 0.01656159, 0.01249594, 0.01168835]),
#    'mean_score_time': array([0.00937037, 0.00938325, 0.00312591, 0.00937409, 0.01114936,
#           0.        , 0.00624962, 0.        , 0.        ]),
#    'std_score_time': array([0.00765088, 0.0076614 , 0.00625181, 0.00765392, 0.00616727,
#           0.        , 0.00765419, 0.        , 0.        ]),
#    'param_classifier__max_depth': masked_array(data=[3, 3, 3, 5, 5, 5, 25, 25, 25],
#                 mask=[False, False, False, False, False, False, False, False,
#                       False],
#           fill_value='?',
#                dtype=object),
#    'param_classifier__max_leaf_nodes': masked_array(data=[10, 20, 100, 10, 20, 100, 10, 20, 100],
#                 mask=[False, False, False, False, False, False, False, False,
#                       False],
#           fill_value='?',
#                dtype=object),
#    'params': [{'classifier__max_depth': 3, 'classifier__max_leaf_nodes': 10},
#     {'classifier__max_depth': 3, 'classifier__max_leaf_nodes': 20},
#     {'classifier__max_depth': 3, 'classifier__max_leaf_nodes': 100},
#     {'classifier__max_depth': 5, 'classifier__max_leaf_nodes': 10},
#     {'classifier__max_depth': 5, 'classifier__max_leaf_nodes': 20},
#     {'classifier__max_depth': 5, 'classifier__max_leaf_nodes': 100},
#     {'classifier__max_depth': 25, 'classifier__max_leaf_nodes': 10},
#     {'classifier__max_depth': 25, 'classifier__max_leaf_nodes': 20},
#     {'classifier__max_depth': 25, 'classifier__max_leaf_nodes': 100}],
#    'split0_test_score': array([0.87930175, 0.87930175, 0.87930175, 0.94912718, 0.94912718,
#           0.94912718, 0.95328346, 0.95527847, 0.95577722]),
#    'split1_test_score': array([0.87645494, 0.87645494, 0.87645494, 0.94712338, 0.94712338,
#           0.94712338, 0.95194546, 0.95344197, 0.95327569]),
#    'split2_test_score': array([0.87662122, 0.87662122, 0.87662122, 0.94579315, 0.94579315,
#           0.94579315, 0.9501164 , 0.95144662, 0.95643499]),
#    'split3_test_score': array([0.86747589, 0.86747589, 0.86747589, 0.94346525, 0.94346525,
#           0.94346525, 0.94812105, 0.95044895, 0.9516129 ]),
#    'split4_test_score': array([0.87229797, 0.87229797, 0.87229797, 0.94196874, 0.94196874,
#           0.94196874, 0.94679082, 0.94945128, 0.95194546]),
#    'mean_test_score': array([0.87443035, 0.87443035, 0.87443035, 0.94549554, 0.94549554,
#           0.94549554, 0.95005144, 0.95201346, 0.95380925]),
#    'std_test_score': array([0.0041362 , 0.0041362 , 0.0041362 , 0.00254903, 0.00254903,
#           0.00254903, 0.00238309, 0.00209927, 0.00196722]),
#    'rank_test_score': array([7, 7, 7, 4, 4, 4, 3, 2, 1])}},
#  'RandomForestClassifier': {'best_params': {'classifier__max_depth': 50,
#    'classifier__max_leaf_nodes': 250,
#    'classifier__n_estimators': 500},
#   'best_score': 0.9539754316680309,
#   'cv_results': {'mean_fit_time': array([ 2.28067827,  6.84113789, 11.68750944,  2.3294827 ,  7.01380835,
#           11.78024259,  2.43213692,  6.91237159, 11.49786835,  2.94375834,
#            8.77102294, 14.49956517,  3.40134978, 10.11109776, 16.89530106,
#            3.7419476 , 11.13043032, 18.41796961,  2.87341166,  8.47893219,
#           14.50651951,  3.40194497, 10.13196936, 16.87491298,  3.70012097,
#           11.26079516, 13.64838037]),
#    'std_fit_time': array([0.02295214, 0.04468996, 0.1812521 , 0.05565055, 0.20062048,
#           0.21914751, 0.12761433, 0.03467565, 0.03449997, 0.00921842,
#           0.01381802, 0.06950789, 0.05525173, 0.03901441, 0.18458615,
#           0.09189889, 0.33169342, 0.1225532 , 0.03600093, 0.11204489,
#           0.06632788, 0.01279202, 0.04578222, 0.1020053 , 0.06741386,
#           0.21464838, 1.57325964]),
#    'mean_score_time': array([0.16562152, 0.50312071, 0.89060616, 0.20311608, 0.57129703,
#           0.8610621 , 0.18749456, 0.52048192, 0.88112364, 0.19374385,
#           0.58740735, 0.97140298, 0.23124762, 0.69686251, 1.15372853,
#           0.25937061, 0.7564631 , 1.24453683, 0.1968698 , 0.59088845,
#           0.97810225, 0.23186078, 0.69426241, 1.16423211, 0.24374857,
#           0.75977831, 0.67957602]),
#    'std_score_time': array([0.00765386, 0.00624487, 0.04419271, 0.03953113, 0.04757837,
#           0.00747972, 0.01397638, 0.00635117, 0.00613646, 0.00765403,
#           0.00587924, 0.01552314, 0.0062475 , 0.00765565, 0.01281368,
#           0.02119335, 0.02084042, 0.00893901, 0.00765479, 0.01394661,
#           0.01874909, 0.00308831, 0.01228051, 0.05877663, 0.00766001,
#           0.04722514, 0.13036466]),
#    'param_classifier__max_depth': masked_array(data=[3, 3, 3, 3, 3, 3, 3, 3, 3, 10, 10, 10, 10, 10, 10, 10,
#                       10, 10, 50, 50, 50, 50, 50, 50, 50, 50, 50],
#                 mask=[False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False],
#           fill_value='?',
#                dtype=object),
#    'param_classifier__max_leaf_nodes': masked_array(data=[20, 20, 20, 100, 100, 100, 250, 250, 250, 20, 20, 20,
#                       100, 100, 100, 250, 250, 250, 20, 20, 20, 100, 100,
#                       100, 250, 250, 250],
#                 mask=[False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False],
#           fill_value='?',
#                dtype=object),
#    'param_classifier__n_estimators': masked_array(data=[100, 300, 500, 100, 300, 500, 100, 300, 500, 100, 300,
#                       500, 100, 300, 500, 100, 300, 500, 100, 300, 500, 100,
#                       300, 500, 100, 300, 500],
#                 mask=[False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False],
#           fill_value='?',
#                dtype=object),
#    'params': [{'classifier__max_depth': 3,
#      'classifier__max_leaf_nodes': 20,
#      'classifier__n_estimators': 100},
#     {'classifier__max_depth': 3,
#      'classifier__max_leaf_nodes': 20,
#      'classifier__n_estimators': 300},
#     {'classifier__max_depth': 3,
#      'classifier__max_leaf_nodes': 20,
#      'classifier__n_estimators': 500},
#     {'classifier__max_depth': 3,
#      'classifier__max_leaf_nodes': 100,
#      'classifier__n_estimators': 100},
#     {'classifier__max_depth': 3,
#      'classifier__max_leaf_nodes': 100,
#      'classifier__n_estimators': 300},
#     {'classifier__max_depth': 3,
#      'classifier__max_leaf_nodes': 100,
#      'classifier__n_estimators': 500},
#     {'classifier__max_depth': 3,
#      'classifier__max_leaf_nodes': 250,
#      'classifier__n_estimators': 100},
#     {'classifier__max_depth': 3,
#      'classifier__max_leaf_nodes': 250,
#      'classifier__n_estimators': 300},
#     {'classifier__max_depth': 3,
#      'classifier__max_leaf_nodes': 250,
#      'classifier__n_estimators': 500},
#     {'classifier__max_depth': 10,
#      'classifier__max_leaf_nodes': 20,
#      'classifier__n_estimators': 100},
#     {'classifier__max_depth': 10,
#      'classifier__max_leaf_nodes': 20,
#      'classifier__n_estimators': 300},
#     {'classifier__max_depth': 10,
#      'classifier__max_leaf_nodes': 20,
#      'classifier__n_estimators': 500},
#     {'classifier__max_depth': 10,
#      'classifier__max_leaf_nodes': 100,
#      'classifier__n_estimators': 100},
#     {'classifier__max_depth': 10,
#      'classifier__max_leaf_nodes': 100,
#      'classifier__n_estimators': 300},
#     {'classifier__max_depth': 10,
#      'classifier__max_leaf_nodes': 100,
#      'classifier__n_estimators': 500},
#     {'classifier__max_depth': 10,
#      'classifier__max_leaf_nodes': 250,
#      'classifier__n_estimators': 100},
#     {'classifier__max_depth': 10,
#      'classifier__max_leaf_nodes': 250,
#      'classifier__n_estimators': 300},
#     {'classifier__max_depth': 10,
#      'classifier__max_leaf_nodes': 250,
#      'classifier__n_estimators': 500},
#     {'classifier__max_depth': 50,
#      'classifier__max_leaf_nodes': 20,
#      'classifier__n_estimators': 100},
#     {'classifier__max_depth': 50,
#      'classifier__max_leaf_nodes': 20,
#      'classifier__n_estimators': 300},
#     {'classifier__max_depth': 50,
#      'classifier__max_leaf_nodes': 20,
#      'classifier__n_estimators': 500},
#     {'classifier__max_depth': 50,
#      'classifier__max_leaf_nodes': 100,
#      'classifier__n_estimators': 100},
#     {'classifier__max_depth': 50,
#      'classifier__max_leaf_nodes': 100,
#      'classifier__n_estimators': 300},
#     {'classifier__max_depth': 50,
#      'classifier__max_leaf_nodes': 100,
#      'classifier__n_estimators': 500},
#     {'classifier__max_depth': 50,
#      'classifier__max_leaf_nodes': 250,
#      'classifier__n_estimators': 100},
#     {'classifier__max_depth': 50,
#      'classifier__max_leaf_nodes': 250,
#      'classifier__n_estimators': 300},
#     {'classifier__max_depth': 50,
#      'classifier__max_leaf_nodes': 250,
#      'classifier__n_estimators': 500}],
#    'split0_test_score': array([0.8719867 , 0.87049044, 0.87215295, 0.8719867 , 0.87049044,
#           0.87215295, 0.8719867 , 0.87049044, 0.87215295, 0.94048213,
#           0.94031588, 0.94081463, 0.95627598, 0.95610973, 0.95644223,
#           0.95727348, 0.95710723, 0.95710723, 0.93915212, 0.93981712,
#           0.94064838, 0.95727348, 0.95710723, 0.95677473, 0.95810474,
#           0.95810474, 0.95876974]),
#    'split1_test_score': array([0.86331892, 0.86132358, 0.86498171, 0.86331892, 0.86132358,
#           0.86498171, 0.86331892, 0.86132358, 0.86498171, 0.9399734 ,
#           0.93781177, 0.93548387, 0.95111407, 0.95111407, 0.9516129 ,
#           0.9516129 , 0.95211174, 0.95227802, 0.94013967, 0.93814433,
#           0.93565015, 0.95194546, 0.95194546, 0.95194546, 0.95360825,
#           0.95360825, 0.95344197]),
#    'split2_test_score': array([0.8689724 , 0.86431659, 0.86647822, 0.8689724 , 0.86431659,
#           0.86647822, 0.8689724 , 0.86431659, 0.86647822, 0.93731294,
#           0.93930828, 0.94097107, 0.94911872, 0.95061523, 0.94995012,
#           0.95111407, 0.95078151, 0.95111407, 0.93731294, 0.93947456,
#           0.94080479, 0.95028267, 0.95044895, 0.95094779, 0.95327569,
#           0.9547722 , 0.9547722 ]),
#    'split3_test_score': array([0.85417359, 0.85483871, 0.85849684, 0.85417359, 0.85483871,
#           0.85849684, 0.85417359, 0.85483871, 0.85849684, 0.93731294,
#           0.93315597, 0.93714666, 0.95044895, 0.95061523, 0.95078151,
#           0.9516129 , 0.95211174, 0.95194546, 0.93698038, 0.93382108,
#           0.93731294, 0.95177918, 0.95111407, 0.95078151, 0.95194546,
#           0.95194546, 0.95144662]),
#    'split4_test_score': array([0.85982707, 0.86148986, 0.86365148, 0.85982707, 0.86148986,
#           0.86365148, 0.85982707, 0.86148986, 0.86365148, 0.94030595,
#           0.94013967, 0.94097107, 0.94845361, 0.949285  , 0.94878617,
#           0.94911872, 0.95061523, 0.95061523, 0.94047223, 0.94013967,
#           0.94097107, 0.949285  , 0.94911872, 0.94945128, 0.95078151,
#           0.95128035, 0.95144662]),
#    'mean_test_score': array([0.86365574, 0.86249184, 0.86515224, 0.86365574, 0.86249184,
#           0.86515224, 0.86365574, 0.86249184, 0.86515224, 0.93907747,
#           0.93814631, 0.93907746, 0.95108227, 0.95154785, 0.95151458,
#           0.95214642, 0.95254549, 0.952612  , 0.93881147, 0.93827935,
#           0.93907746, 0.95211316, 0.95194689, 0.95198015, 0.95354313,
#           0.9539422 , 0.95397543]),
#    'std_test_score': array([0.00636168, 0.00506451, 0.00441234, 0.00636168, 0.00506451,
#           0.00441234, 0.00636168, 0.00506451, 0.00441234, 0.00144997,
#           0.00264749, 0.00231651, 0.00276196, 0.00236046, 0.00263517,
#           0.00272355, 0.00236742, 0.00232352, 0.00143086, 0.00233017,
#           0.00218619, 0.00276108, 0.00274099, 0.00252535, 0.00249251,
#           0.00241659, 0.00270904]),
#    'rank_test_score': array([22, 25, 19, 22, 25, 19, 22, 25, 19, 13, 18, 15, 12, 10, 11,  6,  5,
#            4, 16, 17, 14,  7,  9,  8,  3,  2,  1])}},
#  'KNeighborsClassifier': {'best_params': {'classifier__n_neighbors': 5,
#    'classifier__weights': 'distance'},
#   'best_score': 0.930830600032454,
#   'cv_results': {'mean_fit_time': array([0.23427453, 0.18904247, 0.21561832, 0.22186456, 0.25312128,
#           0.23864269]),
#    'std_fit_time': array([0.02613587, 0.02265818, 0.01822054, 0.01822372, 0.02296337,
#           0.02127931]),
#    'mean_score_time': array([8.90749607, 7.67470417, 8.93905687, 6.43541031, 7.54842234,
#           4.88587451]),
#    'std_score_time': array([0.07368294, 0.4611998 , 0.12046199, 0.76526567, 0.41557831,
#           0.96088896]),
#    'param_classifier__n_neighbors': masked_array(data=[5, 5, 30, 30, 50, 50],
#                 mask=[False, False, False, False, False, False],
#           fill_value='?',
#                dtype=object),
#    'param_classifier__weights': masked_array(data=['uniform', 'distance', 'uniform', 'distance',
#                       'uniform', 'distance'],
#                 mask=[False, False, False, False, False, False],
#           fill_value='?',
#                dtype=object),
#    'params': [{'classifier__n_neighbors': 5, 'classifier__weights': 'uniform'},
#     {'classifier__n_neighbors': 5, 'classifier__weights': 'distance'},
#     {'classifier__n_neighbors': 30, 'classifier__weights': 'uniform'},
#     {'classifier__n_neighbors': 30, 'classifier__weights': 'distance'},
#     {'classifier__n_neighbors': 50, 'classifier__weights': 'uniform'},
#     {'classifier__n_neighbors': 50, 'classifier__weights': 'distance'}],
#    'split0_test_score': array([0.92069825, 0.92385702, 0.91039069, 0.92369077, 0.90124688,
#           0.92236076]),
#    'split1_test_score': array([0.928999  , 0.93332225, 0.908713  , 0.92833389, 0.89923512,
#           0.92600599]),
#    'split2_test_score': array([0.93049551, 0.93498503, 0.90838045, 0.92916528, 0.89574327,
#           0.92650482]),
#    'split3_test_score': array([0.92766877, 0.93265713, 0.90488859, 0.92334553, 0.89491187,
#           0.92401064]),
#    'split4_test_score': array([0.92700366, 0.92933156, 0.90705022, 0.92550715, 0.89424676,
#           0.92168274]),
#    'mean_test_score': array([0.92697304, 0.9308306 , 0.90788459, 0.92600852, 0.89707678,
#           0.92411299]),
#    'std_test_score': array([0.00335768, 0.00394162, 0.00183765, 0.00237012, 0.00270268,
#           0.00191265]),
#    'rank_test_score': array([2, 1, 5, 3, 6, 4])}}}

# %%
Models = [
    'XGBClassifier',
    'LogisticRegression',
    'DecisionTreeClassifier',
    'RandomForestClassifier',
    'KNeighborsClassifier']

Tabs = ['A', 'B', 'C', 'D', 'E']

op_table = pd.DataFrame(columns=['Model','Fit Time (seconds)','Predict Time (seconds)','Test Accuracy (Optimized)'])

for tab, Model in zip(Tabs, Models):
    tab_df = pd.DataFrame(results[Model]['cv_results'])
    num_entries = len(tab_df)  # Get the number of entries in cv_results
    for num in range(num_entries):
        if tab_df['rank_test_score'][num] == 1:
            fit_time = tab_df['mean_fit_time'][num]
            score_time = tab_df['mean_score_time'][num]
            Test_accuracy = tab_df['mean_test_score'][num]
            op_table = pd.concat([op_table,pd.DataFrame({'Model':[Model],'Fit Time (seconds)':[fit_time],
                                                         'Predict Time (seconds)':[score_time],'Test Accuracy (Optimized)':[Test_accuracy]})],ignore_index=True)

# %%
op_table
# Out:
#                     Model  Fit Time (seconds)  Predict Time (seconds)  \
# 0           XGBClassifier            0.945391                0.037495
# 1      LogisticRegression            0.358350                0.003761
# 2  DecisionTreeClassifier            0.065619                0.000000
# 3  RandomForestClassifier           13.648380                0.679576
# 4    KNeighborsClassifier            0.189042                7.674704
#
#    Test Accuracy (Optimized)
# 0                   0.955505
# 1                   0.787470
# 2                   0.953809
# 3                   0.953975
# 4                   0.930831

# %%
compare_table = op_table.merge(result_table_sorted[['Model','Test Accuracy']],how='inner',on='Model')

# %%
compare_table
# Out:
#                     Model  Fit Time (seconds)  Predict Time (seconds)  \
# 0           XGBClassifier            0.945391                0.037495
# 1      LogisticRegression            0.358350                0.003761
# 2  DecisionTreeClassifier            0.065619                0.000000
# 3  RandomForestClassifier           13.648380                0.679576
# 4    KNeighborsClassifier            0.189042                7.674704
#
#    Test Accuracy (Optimized)  Test Accuracy
# 0                   0.955505       0.952745
# 1                   0.787470       0.787536
# 2                   0.953809       0.947990
# 3                   0.953975       0.950251
# 4                   0.930831       0.928070

# %%
compare_table['% Difference'] = (compare_table['Test Accuracy (Optimized)'] - compare_table['Test Accuracy'])*100

# %%
compare_table['% Difference'] = compare_table['% Difference'].map('{:.2f}'.format)

# %%
compare_table = compare_table.sort_values(by='Test Accuracy (Optimized)', ascending=False)

# %%
compare_table
# Out:
#                     Model  Fit Time (seconds)  Predict Time (seconds)  \
# 0           XGBClassifier            0.945391                0.037495
# 3  RandomForestClassifier           13.648380                0.679576
# 2  DecisionTreeClassifier            0.065619                0.000000
# 4    KNeighborsClassifier            0.189042                7.674704
# 1      LogisticRegression            0.358350                0.003761
#
#    Test Accuracy (Optimized)  Test Accuracy % Difference
# 0                   0.955505       0.952745         0.28
# 3                   0.953975       0.950251         0.37
# 2                   0.953809       0.947990         0.58
# 4                   0.930831       0.928070         0.28
# 1                   0.787470       0.787536        -0.01

# %%
plt.subplot(1,2,1)
plt.barh(width=compare_table['Test Accuracy (Optimized)'],y=compare_table['Model'], alpha=0.3, height=0.3, label='Test Accuracy (Optimized)')
plt.barh(width=compare_table['Test Accuracy'],y=compare_table['Model'],align='edge', alpha=0.3, height=0.3, label='Test Accuracy')
plt.legend(loc='upper left')
plt.xlabel('Accuracy - higher is better')
plt.subplot(1,2,2)
plt.plot(compare_table['Fit Time (seconds)'],compare_table['Model'], marker='o', label='Fit Time')
plt.plot(compare_table['Predict Time (seconds)'],compare_table['Model'], marker='x', label='Predict Time')
plt.legend()
plt.xlabel('Time - lower is better')
plt.subplots_adjust(wspace=0.5, right=2)
plt.show()

# %% [markdown]
# # Final Model Evaluation

# %%
#best parameters for Decision Tree model
results['DecisionTreeClassifier']['best_params']
# Out:
# {'classifier__max_depth': 25, 'classifier__max_leaf_nodes': 100}

# %%
dt_op = DecisionTreeClassifier(max_depth=25, max_leaf_nodes=20, random_state=SEED)
dt_op.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=25, max_leaf_nodes=20, random_state=42)

# %%
print('Training Accuracy: ',dt_op.score(x_train,y_train), '\nTest Accuracy: ', dt_op.score(x_test,y_test))
# Out:
# Training Accuracy:  0.9525456419806458
# Test Accuracy:  0.9028299690731935

# %%
y_pred = dt_op.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
dfConfu = confusion_matrix(y_test, y_pred)

# %%
print(dfConfu)
# Out:
# [[14924   429]
#  [ 2493 12225]]

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(dfConfu, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['No Disease', 'Disease'],
            yticklabels=['No Disease', 'Disease'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Decision Tree')
plt.show()

# %%
from sklearn.metrics import classification_report

# %%
report_dt = classification_report(y_test, y_pred, target_names=['No Disease','Disease'])

# %%
print(report_dt)
# Out:
#               precision    recall  f1-score   support
#
#   No Disease       0.86      0.97      0.91     15353
#      Disease       0.97      0.83      0.89     14718
#
#     accuracy                           0.90     30071
#    macro avg       0.91      0.90      0.90     30071
# weighted avg       0.91      0.90      0.90     30071

# %% [markdown]
# <font color="blue">The final Decision Tree model gives a test accuracy of 90% using Test Data.
#
# <font color="blue">Out of the cases predicted with Heart Disease, 97% are actually diagnosed with Heart Disease.
# Out of the cases predicted with no Heart Disease, 86% are actually diagnosed with no Heart Disease.
#
# <font color="blue">From all cases with Heart Disease, 83% are predicted correctly.
# From all cases with no Heart Disease, 97% are predicted correctly.

# %%
feature_importances = dt_op.feature_importances_
feature_names = xy_train.drop('disease', axis=1).columns
sorted_indices = (-feature_importances).argsort()
sorted_feature_names = [feature_names[i] for i in sorted_indices]
sorted_feature_importances = [feature_importances[i] for i in sorted_indices]


plt.figure(figsize=(10, 6))
plt.bar(sorted_feature_names, sorted_feature_importances, align='center')
plt.xlabel('Features')
plt.ylabel('Importance Score')
plt.title('Feature Importance of Decision Tree')
plt.show()

# %% [markdown]
# # Conclusion and Recommendation

# %% [markdown]
# Using clustering before model building requires careful consideration.
#
# First of all, clustering should be carried out after splitting the data to prevent data leakage.
#
# Secondly, When test dataset is too small or not representative of the overall dataset, the clustering may fail. This explains why using different random state, we get very diverse result ranging from single digit accuracy to 85% accuracy. Therefore a sufficiently large test dataset is required to use the clustering technique.
#
# Besides that, the shortcoming of clustering in test dataset will not be able to be reflected in cross validation as cross validation only looks at training dataset. Hence verifying accuracy of the test dataset is required when using clustering in data preprocessing.
#
# Considering the above, 50:50 train test split is performed instead of 70:30. With test data becomes larger, the clustering score becomes more stable with different random state, giving smaller fluctuation.
#
# ![image.png](attachment:3aece30e-fabf-4b4c-b96d-131687136231.png)
#
# With a sufficiently large dataset, clustering in preprocessing step could be quite useful in improving model accuracy.
